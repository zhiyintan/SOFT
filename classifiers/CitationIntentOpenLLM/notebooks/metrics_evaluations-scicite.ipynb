# %% [markdown]
# # Helpers

# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import chi2_contingency
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# %%
metrics_files = [
    glob.glob('../results/scicite/1 - Instruct Q8/*/metrics/*.csv'),
    glob.glob('../results/scicite/1 - Instruct Q8/zero-shot/metrics/*.csv'),
    glob.glob('../results/scicite/1 - Instruct Q8/one-shot/metrics/*.csv'),
    glob.glob('../results/scicite/1 - Instruct Q8/few-shot/metrics/*.csv'),
    glob.glob('../results/scicite/1 - Instruct Q8/many-shot/metrics/*.csv')
]

# %%
def metrics_files_processing(metrics_files, flag):
    data = []
    for m_file in metrics_files:
        # Parse filename to extract metadata
        m_filename = m_file.split('/')[-1]
        parts = m_filename.split('_')

        dataset = parts[2]
        method = parts[3]
        prompt_version = parts[4][2:]  # Remove "SP" prefix
        query_template = parts[5][2:]  # Remove "QT" prefix
        examples_method = parts[6][2:] if "EM" in parts[6] else None  # Handle zero-shot case
        temperature = float(parts[7][1:]) if "T" in parts[7] else float(parts[6][1:]) # Remove "T" prefix

        # Load CSV and add metadata columns
        df = pd.read_csv(m_file)
        df['Dataset'] = dataset
        df['Method'] = method
        df['Prompt_Version'] = prompt_version
        df['Query_Template'] = query_template
        df['Examples_Method'] = examples_method
        df['Temperature'] = temperature
        df['Filename'] = m_filename.split("_metrics_")[-1]

        if flag == 'best':
            # in each dataframe, find the best performing model and set the "best performing" column to 1
            df['Best_Performing'] = 0
            best_f1 = df['F1-Score'].max()
            best_models = df[df['F1-Score'] == best_f1]
            if len(best_models) > 1:
                best_accuracy = best_models['Accuracy'].max()
                df.loc[(df['F1-Score'] == best_f1) & (df['Accuracy'] == best_accuracy), 'Best_Performing'] = 1
            else:
                df.loc[df['F1-Score'] == best_f1, 'Best_Performing'] = 1
        elif flag == 'rank':
            # Sort models by F1-score in descending order
            df = df.sort_values(by=['F1-Score', 'Accuracy'], ascending=[False, False]).reset_index(drop=True)
            # Assign ranking scores (1 for the top model, 1/2 for the second, etc.)
            df['Ranking_Score'] = pd.Series(1 / (df.index + 1)).round(3)
        else:
            raise ValueError(f"Invalid flag: {flag}")

        data.append(df)

    # Concatenate all data
    all_metrics = pd.concat(data, ignore_index=True)
    if flag == 'best':
        all_metrics = all_metrics.sort_values(by=['F1-Score'], ascending=False).reset_index().drop(columns=['index'])
        all_metrics.index += 1
    elif flag == 'rank':
        # Sum the ranking scores for each model across all configurations
        all_metrics = all_metrics.groupby('Model')['Ranking_Score'].sum().reset_index()

        # Sort models by their total ranking score
        all_metrics = all_metrics.sort_values(by='Ranking_Score', ascending=False).reset_index().drop(columns=['index'])
        all_metrics.index += 1
    else:
        raise ValueError(f"Invalid flag: {flag}")

    return all_metrics


def norm_rank(model_scores):
    # Normalize the total ranking scores using Min-Max normalization
    min_score = model_scores['Ranking_Score'].min()
    max_score = model_scores['Ranking_Score'].max()

    model_scores['Normalized_Score'] = (model_scores['Ranking_Score'] - min_score) / (max_score - min_score)

    return model_scores


def plot_rank(model_scores, mode='single', score='rank'):
    if mode == 'single':
        if score == 'rank':
            score_column = [col for col in model_scores.columns if "Ranking_Score" in col]
            score_label = "Rank"
        elif score == 'norm':
            score_column = [col for col in model_scores.columns if "Normalized_Score" in col]
            score_label = "Normalized Rank"

        df_plot = model_scores[["Model"] + score_column].copy()

        df_plot.set_index("Model", inplace=True)
        df_plot.plot(kind='bar', figsize=(10, 6), width=0.8)
        # plt.figure(figsize=(10, 6))
        # plt.barh(model_scores['Model'], score_column, color='skyblue')
        plt.xlabel('Model')
        plt.ylabel(score_label)
        plt.title(f'{score_label}ed Performance by Model')
        # plt.gca().invert_yaxis()
        plt.xticks(rotation=45, ha='right')
        plt.legend().remove()
        plt.tight_layout()
        plt.show()
    elif mode == 'multi':
        if score == 'rank':
            score_columns = [col for col in model_scores.columns if "Ranking_Score" in col]
            score_label = "Rank"
        elif score == 'norm':
            score_columns = [col for col in model_scores.columns if "Normalized_Score" in col]
            score_label = "Normalized Rank"

        # Create a copy of the dataframe with only the relevant columns
        df_plot = model_scores[["Model"] + score_columns].copy()

        # Rename columns to show only the last part after splitting by '_'
        df_plot.rename(columns={col: col.split("_")[-1] for col in score_columns}, inplace=True)
    
        # Set the model names as index
        df_plot.set_index("Model", inplace=True)
        
        # Plot
        df_plot.plot(kind='bar', figsize=(10, 6), width=0.8)
        plt.title(f"{score_label}ed Performance by Model")
        plt.xlabel("Model")
        plt.ylabel(score_label)
        plt.xticks(rotation=45, ha='right')
        plt.legend(loc='upper right')
        plt.tight_layout()
        plt.show()


def merge_rank_dataframes(dataframes, labels, sort=None):
    merged_df = dataframes[0].copy()
    
    merged_df = merged_df.rename(columns={
        "Ranking_Score": f"Ranking_Score_{labels[0]}",
        "Normalized_Score": f"Normalized_Score_{labels[0]}"
    })

    for i in range(1, len(dataframes)):
        df = dataframes[i].copy()
        df = df.rename(columns={
            "Ranking_Score": f"Ranking_Score_{labels[i]}",
            "Normalized_Score": f"Normalized_Score_{labels[i]}"
        })
        merged_df = merged_df.merge(df, on="Model", how="outer")

    if sort is not None:
        merged_df['Model'] = merged_df['Model'].astype("category")
        merged_df['Model'] = merged_df['Model'].cat.set_categories(sort, ordered=True)

        merged_df = merged_df.sort_values("Model").reset_index(drop=True)
        merged_df.index += 1

    return merged_df


def parameter_distributions(metrics, subset, label):
    topK_counts = metrics[metrics['Top'] == 1].value_counts(subset=[subset])
    topK_percent = metrics[metrics['Top'] == 1].value_counts(subset=[subset], normalize=True)

    df_vc = pd.DataFrame({"count": topK_counts, "%": topK_percent*100}).reset_index()
    df_vc.columns = [label, 'Count', 'Percent']
    df_vc.index += 1

    return df_vc

# %% [markdown]
# # Top 50 configurations (sort: F1-score)

# %%
metrics_total = metrics_files_processing(metrics_files[0], flag="best")

display(metrics_total.drop(columns=['Filename']).head(50))
metrics_total.drop(columns=['Best_Performing', 'Filename', 'Dataset']).to_csv('scicite_best_performing_models.csv', index=True)
# Out:
#            Model  Precision  Recall  F1-Score  Accuracy  Dataset     Method  \
# 1    QWEN2.5_14B     0.7827  0.7891    0.7833    0.8071  scicite   few-shot
# 2    QWEN2.5_14B     0.7839  0.7865    0.7831    0.8071  scicite   few-shot
# 3    QWEN2.5_14B     0.7834  0.7865    0.7825    0.8066  scicite   few-shot
# 4    QWEN2.5_14B     0.7800  0.7940    0.7823    0.8076  scicite  many-shot
# 5    QWEN2.5_14B     0.7793  0.7929    0.7813    0.8066  scicite  many-shot
# 6    QWEN2.5_14B     0.7790  0.7922    0.7809    0.8066  scicite  many-shot
# 7    QWEN2.5_14B     0.7807  0.7857    0.7807    0.8049  scicite   few-shot
# 8    QWEN2.5_14B     0.7763  0.7895    0.7802    0.8028  scicite   few-shot
# 9    QWEN2.5_14B     0.7767  0.7929    0.7798    0.8033  scicite  many-shot
# 10   QWEN2.5_14B     0.7760  0.7851    0.7786    0.8023  scicite   few-shot
# 11   QWEN2.5_14B     0.7735  0.7873    0.7777    0.8006  scicite   few-shot
# 12   QWEN2.5_14B     0.7715  0.7905    0.7772    0.8023  scicite  many-shot
# 13   QWEN2.5_14B     0.7737  0.7855    0.7767    0.7996  scicite   few-shot
# 14   QWEN2.5_14B     0.7714  0.7897    0.7763    0.8012  scicite  many-shot
# 15   QWEN2.5_14B     0.7714  0.7880    0.7755    0.8006  scicite  many-shot
# 16   QWEN2.5_14B     0.7704  0.7884    0.7752    0.8006  scicite  many-shot
# 17  MISTRAL_NEMO     0.7911  0.7605    0.7739    0.7910  scicite   few-shot
# 18  MISTRAL_NEMO     0.7820  0.7678    0.7738    0.7958  scicite   few-shot
# 19  MISTRAL_NEMO     0.7929  0.7590    0.7733    0.7926  scicite   few-shot
# 20  MISTRAL_NEMO     0.7665  0.7864    0.7731    0.7834  scicite   few-shot
# 21  MISTRAL_NEMO     0.7680  0.7855    0.7730    0.7845  scicite   few-shot
# 22   QWEN2.5_14B     0.7556  0.8103    0.7721    0.7920  scicite  many-shot
# 23   QWEN2.5_14B     0.7541  0.8091    0.7706    0.7904  scicite  many-shot
# 24   QWEN2.5_14B     0.7521  0.8090    0.7700    0.7898  scicite  many-shot
# 25   QWEN2.5_14B     0.7531  0.8082    0.7696    0.7894  scicite  many-shot
# 26   QWEN2.5_14B     0.7513  0.8091    0.7692    0.7888  scicite  many-shot
# 27   QWEN2.5_14B     0.7507  0.8088    0.7685    0.7883  scicite  many-shot
# 28   QWEN2.5_14B     0.7520  0.8075    0.7683    0.7877  scicite  many-shot
# 29   QWEN2.5_14B     0.7509  0.8009    0.7680    0.7872  scicite   few-shot
# 30   QWEN2.5_14B     0.7486  0.8069    0.7667    0.7861  scicite  many-shot
# 31   QWEN2.5_14B     0.7630  0.7768    0.7664    0.7937  scicite  many-shot
# 32  MISTRAL_NEMO     0.7717  0.7616    0.7658    0.7904  scicite   few-shot
# 33   QWEN2.5_14B     0.7642  0.7691    0.7658    0.7963  scicite   few-shot
# 34   QWEN2.5_14B     0.7468  0.8050    0.7655    0.7845  scicite   few-shot
# 35   QWEN2.5_14B     0.7481  0.7983    0.7653    0.7845  scicite   few-shot
# 36   QWEN2.5_14B     0.7636  0.7733    0.7652    0.7937  scicite  many-shot
# 37   QWEN2.5_14B     0.7473  0.8089    0.7650    0.7834  scicite  many-shot
# 38   QWEN2.5_14B     0.7462  0.8047    0.7648    0.7840  scicite   few-shot
# 39   QWEN2.5_14B     0.7474  0.8071    0.7647    0.7840  scicite  many-shot
# 40   QWEN2.5_14B     0.7477  0.7966    0.7645    0.7840  scicite   few-shot
# 41  MISTRAL_NEMO     0.7686  0.7611    0.7643    0.7877  scicite   few-shot
# 42  MISTRAL_NEMO     0.7466  0.7965    0.7641    0.7851  scicite  many-shot
# 43   QWEN2.5_14B     0.7455  0.8029    0.7639    0.7834  scicite   few-shot
# 44   QWEN2.5_14B     0.7451  0.8030    0.7638    0.7824  scicite   few-shot
# 45   QWEN2.5_14B     0.7462  0.8071    0.7635    0.7824  scicite  many-shot
# 46   QWEN2.5_14B     0.7509  0.7919    0.7632    0.7856  scicite   one-shot
# 47   QWEN2.5_14B     0.7604  0.7678    0.7630    0.7942  scicite   few-shot
# 48   QWEN2.5_14B     0.7496  0.7977    0.7629    0.7834  scicite   one-shot
# 49   QWEN2.5_14B     0.7498  0.7970    0.7627    0.7834  scicite   one-shot
# 50  MISTRAL_NEMO     0.8112  0.7359    0.7625    0.7910  scicite   few-shot
#
#    Prompt_Version Query_Template Examples_Method  Temperature  Best_Performing
# 1               3              2               2          0.5                1
# 2               3              2               2          1.0                1
# 3               3              2               2          0.2                1
# 4               3              2               2          0.0                1
# 5               3              2               2          0.5                1
# 6               3              2               2          0.2                1
# 7               3              2               2          0.0                1
# 8               2              2               2          0.0                1
# 9               3              2               2          1.0                1
# 10              2              2               2          1.0                1
# 11              2              2               2          0.2                1
# 12              2              2               2          1.0                1
# 13              2              2               2          0.5                1
# 14              2              2               2          0.2                1
# 15              2              2               2          0.0                1
# 16              2              2               2          0.5                1
# 17              1              1               1          0.2                1
# 18              2              2               1          0.0                1
# 19              1              1               1          0.0                1
# 20              1              2               1          0.2                1
# 21              1              2               1          0.0                1
# 22              3              2               1          0.5                1
# 23              3              2               1          0.0                1
# 24              1              2               1          0.0                1
# 25              3              2               1          0.2                1
# 26              1              2               1          0.2                1
# 27              1              2               1          0.5                1
# 28              3              2               1          1.0                1
# 29              3              2               1          0.2                1
# 30              1              2               1          1.0                1
# 31              1              2               2          1.0                1
# 32              2              2               1          0.2                1
# 33              1              2               2          1.0                1
# 34              1              2               1          0.2                0
# 35              3              2               1          0.0                1
# 36              1              2               2          0.2                1
# 37              2              2               1          0.2                1
# 38              1              2               1          0.0                0
# 39              2              2               1          1.0                1
# 40              3              2               1          0.5                1
# 41              2              2               1          0.5                1
# 42              2              2               1          0.2                0
# 43              1              2               1          0.5                1
# 44              1              2               1          1.0                1
# 45              2              2               1          0.0                1
# 46              1              2               1          1.0                1
# 47              1              2               2          0.5                1
# 48              3              2               2          1.0                1
# 49              3              2               2          0.5                1
# 50              2              1               1          0.0                1

# %% [markdown]
# # Best Performing Models per Configuration

# %%
# display only the best performing models
best_performing = metrics_total[metrics_total['Best_Performing'] == 1]

# Group by 'Model' and 'Method' and count occurrences for each combination
method_counts = best_performing.groupby(['Model', 'Method']).size().unstack(fill_value=0)
method_counts = method_counts[['zero-shot', 'one-shot', 'few-shot', 'many-shot']]

# create a new dataframe with two columns: The model name, and the count of how many times it was the best performing model
best_performing_counts = best_performing['Model'].value_counts().reset_index()
best_performing_counts.columns = ['Model', 'Best Performing Count']
best_performing_counts = best_performing_counts.merge(method_counts, on='Model', how='left')
best_performing_counts.index += 1
display(best_performing_counts)
# Out:
#           Model  Best Performing Count  zero-shot  one-shot  few-shot  \
# 1   QWEN2.5_14B                    114         20        38        27
# 2  MISTRAL_NEMO                     20          0         0        11
# 3     GEMMA2-9B                      4          0         2         2
# 4    GEMMA2-27B                      2          0         0         0
#
#    many-shot
# 1         29
# 2          9
# 3          0
# 4          2

# %% [markdown]
# ### Best Qwen 2.5 14B

# %%
best_performing_qwen = best_performing[best_performing['Model'] == 'QWEN2.5_14B'].sort_values(by='F1-Score', ascending=False).reset_index().drop(columns=['Model', 'Dataset', 'Best_Performing', 'index'])
best_performing_qwen.index += 1

# print(best_performing_qwen.value_counts(subset=['Method']))
display(best_performing_qwen)
# Out:
#      Precision  Recall  F1-Score  Accuracy     Method Prompt_Version  \
# 1       0.7827  0.7891    0.7833    0.8071   few-shot              3
# 2       0.7839  0.7865    0.7831    0.8071   few-shot              3
# 3       0.7834  0.7865    0.7825    0.8066   few-shot              3
# 4       0.7800  0.7940    0.7823    0.8076  many-shot              3
# 5       0.7793  0.7929    0.7813    0.8066  many-shot              3
# 6       0.7790  0.7922    0.7809    0.8066  many-shot              3
# 7       0.7807  0.7857    0.7807    0.8049   few-shot              3
# 8       0.7763  0.7895    0.7802    0.8028   few-shot              2
# 9       0.7767  0.7929    0.7798    0.8033  many-shot              3
# 10      0.7760  0.7851    0.7786    0.8023   few-shot              2
# 11      0.7735  0.7873    0.7777    0.8006   few-shot              2
# 12      0.7715  0.7905    0.7772    0.8023  many-shot              2
# 13      0.7737  0.7855    0.7767    0.7996   few-shot              2
# 14      0.7714  0.7897    0.7763    0.8012  many-shot              2
# 15      0.7714  0.7880    0.7755    0.8006  many-shot              2
# 16      0.7704  0.7884    0.7752    0.8006  many-shot              2
# 17      0.7556  0.8103    0.7721    0.7920  many-shot              3
# 18      0.7541  0.8091    0.7706    0.7904  many-shot              3
# 19      0.7521  0.8090    0.7700    0.7898  many-shot              1
# 20      0.7531  0.8082    0.7696    0.7894  many-shot              3
# 21      0.7513  0.8091    0.7692    0.7888  many-shot              1
# 22      0.7507  0.8088    0.7685    0.7883  many-shot              1
# 23      0.7520  0.8075    0.7683    0.7877  many-shot              3
# 24      0.7509  0.8009    0.7680    0.7872   few-shot              3
# 25      0.7486  0.8069    0.7667    0.7861  many-shot              1
# 26      0.7630  0.7768    0.7664    0.7937  many-shot              1
# 27      0.7642  0.7691    0.7658    0.7963   few-shot              1
# 28      0.7481  0.7983    0.7653    0.7845   few-shot              3
# 29      0.7636  0.7733    0.7652    0.7937  many-shot              1
# 30      0.7473  0.8089    0.7650    0.7834  many-shot              2
# 31      0.7474  0.8071    0.7647    0.7840  many-shot              2
# 32      0.7477  0.7966    0.7645    0.7840   few-shot              3
# 33      0.7455  0.8029    0.7639    0.7834   few-shot              1
# 34      0.7451  0.8030    0.7638    0.7824   few-shot              1
# 35      0.7462  0.8071    0.7635    0.7824  many-shot              2
# 36      0.7509  0.7919    0.7632    0.7856   one-shot              1
# 37      0.7604  0.7678    0.7630    0.7942   few-shot              1
# 38      0.7496  0.7977    0.7629    0.7834   one-shot              3
# 39      0.7498  0.7970    0.7627    0.7834   one-shot              3
# 40      0.7456  0.8065    0.7625    0.7818  many-shot              2
# 41      0.7496  0.7970    0.7625    0.7834   one-shot              3
# 42      0.7504  0.7914    0.7623    0.7851   one-shot              1
# 43      0.7447  0.7961    0.7620    0.7813   few-shot              3
# 44      0.7485  0.7963    0.7617    0.7824   one-shot              3
# 45      0.7599  0.7692    0.7614    0.7904  many-shot              1
# 46      0.7592  0.7654    0.7614    0.7931   few-shot              1
# 47      0.7589  0.7681    0.7606    0.7904  many-shot              1
# 48      0.7484  0.7896    0.7603    0.7834   one-shot              1
# 49      0.7580  0.7638    0.7601    0.7920   few-shot              1
# 50      0.7415  0.7983    0.7597    0.7781   few-shot              2
# 51      0.7474  0.7888    0.7593    0.7824   one-shot              1
# 52      0.7478  0.7864    0.7587    0.7824   one-shot              1
# 53      0.7456  0.7818    0.7556    0.7802   one-shot              1
# 54      0.7448  0.7817    0.7551    0.7797   one-shot              1
# 55      0.7435  0.7810    0.7538    0.7786   one-shot              1
# 56      0.7476  0.7839    0.7526    0.7770  zero-shot              3
# 57      0.7487  0.7819    0.7522    0.7770  zero-shot              3
# 58      0.7468  0.7836    0.7520    0.7765  zero-shot              3
# 59      0.7401  0.7817    0.7508    0.7749   one-shot              2
# 60      0.7376  0.7862    0.7506    0.7722   one-shot              3
# 61      0.7373  0.7864    0.7504    0.7722   one-shot              3
# 62      0.7386  0.7825    0.7502    0.7722   one-shot              2
# 63      0.7413  0.7813    0.7499    0.7732  zero-shot              2
# 64      0.7369  0.7849    0.7499    0.7716   one-shot              3
# 65      0.7388  0.7815    0.7498    0.7716   one-shot              2
# 66      0.7500  0.7515    0.7498    0.7663   one-shot              1
# 67      0.7389  0.7815    0.7497    0.7716   one-shot              2
# 68      0.7384  0.7815    0.7495    0.7716   one-shot              2
# 69      0.7453  0.7804    0.7495    0.7743  zero-shot              3
# 70      0.7408  0.7812    0.7494    0.7722  zero-shot              2
# 71      0.7396  0.7813    0.7490    0.7722  zero-shot              2
# 72      0.7358  0.7845    0.7489    0.7711   one-shot              3
# 73      0.7385  0.7786    0.7488    0.7732   one-shot              2
# 74      0.7479  0.7504    0.7483    0.7652   one-shot              1
# 75      0.7373  0.7793    0.7480    0.7716   one-shot              2
# 76      0.7376  0.7787    0.7479    0.7722   one-shot              2
# 77      0.7483  0.7491    0.7476    0.7663   one-shot              1
# 78      0.7381  0.7787    0.7475    0.7706  zero-shot              2
# 79      0.7482  0.7485    0.7473    0.7636   one-shot              1
# 80      0.7332  0.7778    0.7455    0.7668  zero-shot              1
# 81      0.7271  0.7768    0.7448    0.7501   few-shot              1
# 82      0.7264  0.7764    0.7441    0.7496   few-shot              1
# 83      0.7367  0.7503    0.7430    0.7630   one-shot              2
# 84      0.7250  0.7738    0.7424    0.7485   few-shot              1
# 85      0.7307  0.7746    0.7423    0.7641  zero-shot              1
# 86      0.7305  0.7746    0.7421    0.7641  zero-shot              1
# 87      0.7358  0.7489    0.7419    0.7620   one-shot              2
# 88      0.7360  0.7474    0.7414    0.7620   one-shot              2
# 89      0.7301  0.7743    0.7414    0.7636  zero-shot              1
# 90      0.7278  0.7875    0.7403    0.7609  zero-shot              2
# 91      0.7218  0.7714    0.7395    0.7448   few-shot              1
# 92      0.7311  0.7505    0.7394    0.7593   one-shot              1
# 93      0.7217  0.7679    0.7394    0.7507   few-shot              2
# 94      0.7329  0.7459    0.7390    0.7614   one-shot              2
# 95      0.7293  0.7525    0.7390    0.7587   one-shot              1
# 96      0.7207  0.7672    0.7383    0.7507   few-shot              2
# 97      0.7279  0.7513    0.7377    0.7571   one-shot              1
# 98      0.7253  0.7852    0.7373    0.7577  zero-shot              2
# 99      0.7266  0.7504    0.7366    0.7566   one-shot              1
# 100     0.7244  0.7842    0.7366    0.7571  zero-shot              2
# 101     0.7244  0.7842    0.7366    0.7571  zero-shot              2
# 102     0.7184  0.7649    0.7360    0.7485   few-shot              2
# 103     0.7179  0.7650    0.7358    0.7469   few-shot              2
# 104     0.7240  0.7907    0.7355    0.7544  zero-shot              1
# 105     0.7237  0.7901    0.7348    0.7539  zero-shot              1
# 106     0.7232  0.7898    0.7343    0.7534  zero-shot              1
# 107     0.7140  0.7799    0.7333    0.7458  many-shot              1
# 108     0.7219  0.7884    0.7329    0.7517  zero-shot              1
# 109     0.7177  0.7578    0.7317    0.7507   one-shot              2
# 110     0.7124  0.7768    0.7316    0.7442  many-shot              1
# 111     0.7161  0.7566    0.7302    0.7491   one-shot              2
# 112     0.7100  0.7766    0.7290    0.7421  many-shot              1
# 113     0.6990  0.7825    0.7044    0.7168  many-shot              1
# 114     0.6950  0.7748    0.6964    0.7098  many-shot              2
#
#     Query_Template Examples_Method  Temperature  \
# 1                2               2          0.5
# 2                2               2          1.0
# 3                2               2          0.2
# 4                2               2          0.0
# 5                2               2          0.5
# 6                2               2          0.2
# 7                2               2          0.0
# 8                2               2          0.0
# 9                2               2          1.0
# 10               2               2          1.0
# 11               2               2          0.2
# 12               2               2          1.0
# 13               2               2          0.5
# 14               2               2          0.2
# 15               2               2          0.0
# 16               2               2          0.5
# 17               2               1          0.5
# 18               2               1          0.0
# 19               2               1          0.0
# 20               2               1          0.2
# 21               2               1          0.2
# 22               2               1          0.5
# 23               2               1          1.0
# 24               2               1          0.2
# 25               2               1          1.0
# 26               2               2          1.0
# 27               2               2          1.0
# 28               2               1          0.0
# 29               2               2          0.2
# 30               2               1          0.2
# 31               2               1          1.0
# 32               2               1          0.5
# 33               2               1          0.5
# 34               2               1          1.0
# 35               2               1          0.0
# 36               2               1          1.0
# 37               2               2          0.5
# 38               2               2          1.0
# 39               2               2          0.5
# 40               2               1          0.5
# 41               2               2          0.0
# 42               2               1          0.5
# 43               2               1          1.0
# 44               2               2          0.2
# 45               2               2          0.0
# 46               2               2          0.0
# 47               2               2          0.5
# 48               2               1          0.0
# 49               2               2          0.2
# 50               2               1          1.0
# 51               2               1          0.2
# 52               2               2          0.5
# 53               2               2          0.0
# 54               2               2          0.2
# 55               2               2          1.0
# 56               2            None          0.2
# 57               2            None          1.0
# 58               2            None          0.0
# 59               2               2          0.5
# 60               2               1          0.0
# 61               2               1          0.2
# 62               2               1          1.0
# 63               1            None          0.0
# 64               2               1          0.5
# 65               2               1          0.2
# 66               1               2          0.2
# 67               2               1          0.0
# 68               2               1          0.5
# 69               2            None          0.5
# 70               1            None          0.5
# 71               1            None          0.2
# 72               2               1          1.0
# 73               2               2          0.2
# 74               1               2          0.5
# 75               2               2          1.0
# 76               2               2          0.0
# 77               1               2          1.0
# 78               1            None          1.0
# 79               1               2          0.0
# 80               1            None          1.0
# 81               1               2          0.5
# 82               1               2          0.0
# 83               1               2          0.2
# 84               1               2          0.2
# 85               1            None          0.2
# 86               1            None          0.0
# 87               1               2          0.0
# 88               1               2          0.5
# 89               1            None          0.5
# 90               2            None          1.0
# 91               1               2          1.0
# 92               1               1          0.5
# 93               1               2          0.5
# 94               1               2          1.0
# 95               1               1          0.0
# 96               1               2          0.0
# 97               1               1          0.2
# 98               2            None          0.5
# 99               1               1          1.0
# 100              2            None          0.0
# 101              2            None          0.2
# 102              1               2          0.2
# 103              1               2          1.0
# 104              2            None          0.5
# 105              2            None          0.2
# 106              2            None          0.0
# 107              1               2          0.0
# 108              2            None          1.0
# 109              1               1          0.2
# 110              1               2          0.5
# 111              1               1          0.0
# 112              1               2          1.0
# 113              1               1          1.0
# 114              1               1          1.0
#
#                                       Filename
# 1     scicite_few-shot_SP3_QT2_EM2_T0.5_Q8.csv
# 2     scicite_few-shot_SP3_QT2_EM2_T1.0_Q8.csv
# 3     scicite_few-shot_SP3_QT2_EM2_T0.2_Q8.csv
# 4    scicite_many-shot_SP3_QT2_EM2_T0.0_Q8.csv
# 5    scicite_many-shot_SP3_QT2_EM2_T0.5_Q8.csv
# 6    scicite_many-shot_SP3_QT2_EM2_T0.2_Q8.csv
# 7     scicite_few-shot_SP3_QT2_EM2_T0.0_Q8.csv
# 8     scicite_few-shot_SP2_QT2_EM2_T0.0_Q8.csv
# 9    scicite_many-shot_SP3_QT2_EM2_T1.0_Q8.csv
# 10    scicite_few-shot_SP2_QT2_EM2_T1.0_Q8.csv
# 11    scicite_few-shot_SP2_QT2_EM2_T0.2_Q8.csv
# 12   scicite_many-shot_SP2_QT2_EM2_T1.0_Q8.csv
# 13    scicite_few-shot_SP2_QT2_EM2_T0.5_Q8.csv
# 14   scicite_many-shot_SP2_QT2_EM2_T0.2_Q8.csv
# 15   scicite_many-shot_SP2_QT2_EM2_T0.0_Q8.csv
# 16   scicite_many-shot_SP2_QT2_EM2_T0.5_Q8.csv
# 17   scicite_many-shot_SP3_QT2_EM1_T0.5_Q8.csv
# 18   scicite_many-shot_SP3_QT2_EM1_T0.0_Q8.csv
# 19   scicite_many-shot_SP1_QT2_EM1_T0.0_Q8.csv
# 20   scicite_many-shot_SP3_QT2_EM1_T0.2_Q8.csv
# 21   scicite_many-shot_SP1_QT2_EM1_T0.2_Q8.csv
# 22   scicite_many-shot_SP1_QT2_EM1_T0.5_Q8.csv
# 23   scicite_many-shot_SP3_QT2_EM1_T1.0_Q8.csv
# 24    scicite_few-shot_SP3_QT2_EM1_T0.2_Q8.csv
# 25   scicite_many-shot_SP1_QT2_EM1_T1.0_Q8.csv
# 26   scicite_many-shot_SP1_QT2_EM2_T1.0_Q8.csv
# 27    scicite_few-shot_SP1_QT2_EM2_T1.0_Q8.csv
# 28    scicite_few-shot_SP3_QT2_EM1_T0.0_Q8.csv
# 29   scicite_many-shot_SP1_QT2_EM2_T0.2_Q8.csv
# 30   scicite_many-shot_SP2_QT2_EM1_T0.2_Q8.csv
# 31   scicite_many-shot_SP2_QT2_EM1_T1.0_Q8.csv
# 32    scicite_few-shot_SP3_QT2_EM1_T0.5_Q8.csv
# 33    scicite_few-shot_SP1_QT2_EM1_T0.5_Q8.csv
# 34    scicite_few-shot_SP1_QT2_EM1_T1.0_Q8.csv
# 35   scicite_many-shot_SP2_QT2_EM1_T0.0_Q8.csv
# 36    scicite_one-shot_SP1_QT2_EM1_T1.0_Q8.csv
# 37    scicite_few-shot_SP1_QT2_EM2_T0.5_Q8.csv
# 38    scicite_one-shot_SP3_QT2_EM2_T1.0_Q8.csv
# 39    scicite_one-shot_SP3_QT2_EM2_T0.5_Q8.csv
# 40   scicite_many-shot_SP2_QT2_EM1_T0.5_Q8.csv
# 41    scicite_one-shot_SP3_QT2_EM2_T0.0_Q8.csv
# 42    scicite_one-shot_SP1_QT2_EM1_T0.5_Q8.csv
# 43    scicite_few-shot_SP3_QT2_EM1_T1.0_Q8.csv
# 44    scicite_one-shot_SP3_QT2_EM2_T0.2_Q8.csv
# 45   scicite_many-shot_SP1_QT2_EM2_T0.0_Q8.csv
# 46    scicite_few-shot_SP1_QT2_EM2_T0.0_Q8.csv
# 47   scicite_many-shot_SP1_QT2_EM2_T0.5_Q8.csv
# 48    scicite_one-shot_SP1_QT2_EM1_T0.0_Q8.csv
# 49    scicite_few-shot_SP1_QT2_EM2_T0.2_Q8.csv
# 50    scicite_few-shot_SP2_QT2_EM1_T1.0_Q8.csv
# 51    scicite_one-shot_SP1_QT2_EM1_T0.2_Q8.csv
# 52    scicite_one-shot_SP1_QT2_EM2_T0.5_Q8.csv
# 53    scicite_one-shot_SP1_QT2_EM2_T0.0_Q8.csv
# 54    scicite_one-shot_SP1_QT2_EM2_T0.2_Q8.csv
# 55    scicite_one-shot_SP1_QT2_EM2_T1.0_Q8.csv
# 56       scicite_zero-shot_SP3_QT2_T0.2_Q8.csv
# 57       scicite_zero-shot_SP3_QT2_T1.0_Q8.csv
# 58       scicite_zero-shot_SP3_QT2_T0.0_Q8.csv
# 59    scicite_one-shot_SP2_QT2_EM2_T0.5_Q8.csv
# 60    scicite_one-shot_SP3_QT2_EM1_T0.0_Q8.csv
# 61    scicite_one-shot_SP3_QT2_EM1_T0.2_Q8.csv
# 62    scicite_one-shot_SP2_QT2_EM1_T1.0_Q8.csv
# 63       scicite_zero-shot_SP2_QT1_T0.0_Q8.csv
# 64    scicite_one-shot_SP3_QT2_EM1_T0.5_Q8.csv
# 65    scicite_one-shot_SP2_QT2_EM1_T0.2_Q8.csv
# 66    scicite_one-shot_SP1_QT1_EM2_T0.2_Q8.csv
# 67    scicite_one-shot_SP2_QT2_EM1_T0.0_Q8.csv
# 68    scicite_one-shot_SP2_QT2_EM1_T0.5_Q8.csv
# 69       scicite_zero-shot_SP3_QT2_T0.5_Q8.csv
# 70       scicite_zero-shot_SP2_QT1_T0.5_Q8.csv
# 71       scicite_zero-shot_SP2_QT1_T0.2_Q8.csv
# 72    scicite_one-shot_SP3_QT2_EM1_T1.0_Q8.csv
# 73    scicite_one-shot_SP2_QT2_EM2_T0.2_Q8.csv
# 74    scicite_one-shot_SP1_QT1_EM2_T0.5_Q8.csv
# 75    scicite_one-shot_SP2_QT2_EM2_T1.0_Q8.csv
# 76    scicite_one-shot_SP2_QT2_EM2_T0.0_Q8.csv
# 77    scicite_one-shot_SP1_QT1_EM2_T1.0_Q8.csv
# 78       scicite_zero-shot_SP2_QT1_T1.0_Q8.csv
# 79    scicite_one-shot_SP1_QT1_EM2_T0.0_Q8.csv
# 80       scicite_zero-shot_SP1_QT1_T1.0_Q8.csv
# 81    scicite_few-shot_SP1_QT1_EM2_T0.5_Q8.csv
# 82    scicite_few-shot_SP1_QT1_EM2_T0.0_Q8.csv
# 83    scicite_one-shot_SP2_QT1_EM2_T0.2_Q8.csv
# 84    scicite_few-shot_SP1_QT1_EM2_T0.2_Q8.csv
# 85       scicite_zero-shot_SP1_QT1_T0.2_Q8.csv
# 86       scicite_zero-shot_SP1_QT1_T0.0_Q8.csv
# 87    scicite_one-shot_SP2_QT1_EM2_T0.0_Q8.csv
# 88    scicite_one-shot_SP2_QT1_EM2_T0.5_Q8.csv
# 89       scicite_zero-shot_SP1_QT1_T0.5_Q8.csv
# 90       scicite_zero-shot_SP2_QT2_T1.0_Q8.csv
# 91    scicite_few-shot_SP1_QT1_EM2_T1.0_Q8.csv
# 92    scicite_one-shot_SP1_QT1_EM1_T0.5_Q8.csv
# 93    scicite_few-shot_SP2_QT1_EM2_T0.5_Q8.csv
# 94    scicite_one-shot_SP2_QT1_EM2_T1.0_Q8.csv
# 95    scicite_one-shot_SP1_QT1_EM1_T0.0_Q8.csv
# 96    scicite_few-shot_SP2_QT1_EM2_T0.0_Q8.csv
# 97    scicite_one-shot_SP1_QT1_EM1_T0.2_Q8.csv
# 98       scicite_zero-shot_SP2_QT2_T0.5_Q8.csv
# 99    scicite_one-shot_SP1_QT1_EM1_T1.0_Q8.csv
# 100      scicite_zero-shot_SP2_QT2_T0.0_Q8.csv
# 101      scicite_zero-shot_SP2_QT2_T0.2_Q8.csv
# 102   scicite_few-shot_SP2_QT1_EM2_T0.2_Q8.csv
# 103   scicite_few-shot_SP2_QT1_EM2_T1.0_Q8.csv
# 104      scicite_zero-shot_SP1_QT2_T0.5_Q8.csv
# 105      scicite_zero-shot_SP1_QT2_T0.2_Q8.csv
# 106      scicite_zero-shot_SP1_QT2_T0.0_Q8.csv
# 107  scicite_many-shot_SP1_QT1_EM2_T0.0_Q8.csv
# 108      scicite_zero-shot_SP1_QT2_T1.0_Q8.csv
# 109   scicite_one-shot_SP2_QT1_EM1_T0.2_Q8.csv
# 110  scicite_many-shot_SP1_QT1_EM2_T0.5_Q8.csv
# 111   scicite_one-shot_SP2_QT1_EM1_T0.0_Q8.csv
# 112  scicite_many-shot_SP1_QT1_EM2_T1.0_Q8.csv
# 113  scicite_many-shot_SP1_QT1_EM1_T1.0_Q8.csv
# 114  scicite_many-shot_SP2_QT1_EM1_T1.0_Q8.csv

# %% [markdown]
# ### Best MISTRAL NEMO

# %%
best_performing_mistral = best_performing[best_performing['Model'] == 'MISTRAL_NEMO'].sort_values(by='F1-Score', ascending=False).reset_index().drop(columns=['Model', 'Dataset', 'Best_Performing', 'index'])
best_performing_mistral.index += 1

display(best_performing_mistral)
# Out:
#     Precision  Recall  F1-Score  Accuracy     Method Prompt_Version  \
# 1      0.7911  0.7605    0.7739    0.7910   few-shot              1
# 2      0.7820  0.7678    0.7738    0.7958   few-shot              2
# 3      0.7929  0.7590    0.7733    0.7926   few-shot              1
# 4      0.7665  0.7864    0.7731    0.7834   few-shot              1
# 5      0.7680  0.7855    0.7730    0.7845   few-shot              1
# 6      0.7717  0.7616    0.7658    0.7904   few-shot              2
# 7      0.7686  0.7611    0.7643    0.7877   few-shot              2
# 8      0.8112  0.7359    0.7625    0.7910   few-shot              2
# 9      0.8090  0.7329    0.7594    0.7845   few-shot              2
# 10     0.7927  0.7295    0.7534    0.7759  many-shot              2
# 11     0.7878  0.7297    0.7520    0.7765  many-shot              2
# 12     0.7933  0.7265    0.7508    0.7759   few-shot              2
# 13     0.7442  0.7513    0.7472    0.7593  many-shot              1
# 14     0.7556  0.7390    0.7465    0.7680   few-shot              1
# 15     0.7382  0.7462    0.7417    0.7534  many-shot              1
# 16     0.7637  0.7353    0.7389    0.7646  many-shot              2
# 17     0.7589  0.7323    0.7356    0.7625  many-shot              2
# 18     0.7386  0.7419    0.7321    0.7560  many-shot              1
# 19     0.7479  0.7000    0.7188    0.7457  many-shot              2
# 20     0.7078  0.7301    0.7177    0.7311  many-shot              1
#
#    Query_Template Examples_Method  Temperature  \
# 1               1               1          0.2
# 2               2               1          0.0
# 3               1               1          0.0
# 4               2               1          0.2
# 5               2               1          0.0
# 6               2               1          0.2
# 7               2               1          0.5
# 8               1               1          0.0
# 9               1               1          0.2
# 10              1               1          0.0
# 11              1               1          0.2
# 12              1               1          0.5
# 13              1               1          0.0
# 14              1               1          0.5
# 15              1               1          0.2
# 16              1               2          0.0
# 17              1               2          0.2
# 18              1               2          0.2
# 19              1               1          0.5
# 20              1               1          0.5
#
#                                      Filename
# 1    scicite_few-shot_SP1_QT1_EM1_T0.2_Q8.csv
# 2    scicite_few-shot_SP2_QT2_EM1_T0.0_Q8.csv
# 3    scicite_few-shot_SP1_QT1_EM1_T0.0_Q8.csv
# 4    scicite_few-shot_SP1_QT2_EM1_T0.2_Q8.csv
# 5    scicite_few-shot_SP1_QT2_EM1_T0.0_Q8.csv
# 6    scicite_few-shot_SP2_QT2_EM1_T0.2_Q8.csv
# 7    scicite_few-shot_SP2_QT2_EM1_T0.5_Q8.csv
# 8    scicite_few-shot_SP2_QT1_EM1_T0.0_Q8.csv
# 9    scicite_few-shot_SP2_QT1_EM1_T0.2_Q8.csv
# 10  scicite_many-shot_SP2_QT1_EM1_T0.0_Q8.csv
# 11  scicite_many-shot_SP2_QT1_EM1_T0.2_Q8.csv
# 12   scicite_few-shot_SP2_QT1_EM1_T0.5_Q8.csv
# 13  scicite_many-shot_SP1_QT1_EM1_T0.0_Q8.csv
# 14   scicite_few-shot_SP1_QT1_EM1_T0.5_Q8.csv
# 15  scicite_many-shot_SP1_QT1_EM1_T0.2_Q8.csv
# 16  scicite_many-shot_SP2_QT1_EM2_T0.0_Q8.csv
# 17  scicite_many-shot_SP2_QT1_EM2_T0.2_Q8.csv
# 18  scicite_many-shot_SP1_QT1_EM2_T0.2_Q8.csv
# 19  scicite_many-shot_SP2_QT1_EM1_T0.5_Q8.csv
# 20  scicite_many-shot_SP1_QT1_EM1_T0.5_Q8.csv

# %% [markdown]
# ### Best GEMMA 2 - 9B

# %%
best_performing_gemma2_9b = best_performing[best_performing['Model'] == 'GEMMA2-9B'].sort_values(by='F1-Score', ascending=False).reset_index().drop(columns=['Model', 'Dataset', 'Best_Performing', 'index'])
best_performing_gemma2_9b.index += 1

display(best_performing_gemma2_9b)
# Out:
#    Precision  Recall  F1-Score  Accuracy    Method Prompt_Version  \
# 1     0.7397  0.7508    0.7337    0.7593  one-shot              2
# 2     0.7347  0.7489    0.7307    0.7550  one-shot              2
# 3     0.7053  0.7301    0.7070    0.7319  few-shot              2
# 4     0.6947  0.7407    0.7041    0.7222  few-shot              1
#
#   Query_Template Examples_Method  Temperature  \
# 1              1               1          0.5
# 2              1               1          1.0
# 3              1               1          1.0
# 4              1               1          1.0
#
#                                    Filename
# 1  scicite_one-shot_SP2_QT1_EM1_T0.5_Q8.csv
# 2  scicite_one-shot_SP2_QT1_EM1_T1.0_Q8.csv
# 3  scicite_few-shot_SP2_QT1_EM1_T1.0_Q8.csv
# 4  scicite_few-shot_SP1_QT1_EM1_T1.0_Q8.csv

# %% [markdown]
# ### Best GEMMA 2 - 27B

# %%
best_performing_gemma2_27b = best_performing[best_performing['Model'] == 'GEMMA2-27B'].sort_values(by='F1-Score', ascending=False).reset_index().drop(columns=['Model', 'Dataset', 'Best_Performing', 'index'])
best_performing_gemma2_27b.index += 1

display(best_performing_gemma2_27b)
# Out:
#    Precision  Recall  F1-Score  Accuracy     Method Prompt_Version  \
# 1     0.7225  0.7479    0.7287    0.7566  many-shot              2
# 2     0.7226  0.7482    0.7284    0.7544  many-shot              2
#
#   Query_Template Examples_Method  Temperature  \
# 1              1               2          1.0
# 2              1               2          0.5
#
#                                     Filename
# 1  scicite_many-shot_SP2_QT1_EM2_T1.0_Q8.csv
# 2  scicite_many-shot_SP2_QT1_EM2_T0.5_Q8.csv

# %% [markdown]
# # Ranked Model Performance

# %% [markdown]
# ### 1. Ranking Models in Each Configuration
#
# For a given experimental configuration $c$ , let:
#
# * $M = m_1, m_2, \dots, m_n$  be the set of models evaluated in configuration $c$.
# * $\text{F1}(m_i, c)$ be the F1-score of model $m_i$ in configuration $c$.
#
# Sort the models in $M$ by their F1-scores in descending order:
#
# * $\text{F1}(m_{1}, c) \geq \text{F1}(m_{2}, c) \geq \dots \geq \text{F1}(m_{n}, c)$
#
# where $m_{k}$  is the  $k$-th ranked model in configuration $c$.
#
# ### 2. Assigning Scores Based on Rank
#
# For each model $m_{k}$  in configuration $c$, assign a score $S(m_{k}, c)$ based on its rank $k$:
#
# * $S(m_{k}, c) = \frac{1}{k}$
#
# ### 3. Aggregating Scores Across Configurations
#
# Let $C$ be the set of all configurations. For each model $m$, calculate the total score $Rank(m)$ by summing its scores across all configurations $c \in C$:
#
# * $Rank(m) = \sum_{c \in C} S(m, c)$
#
# where $S(m, c)$ is the score assigned to model $m$ in configuration $c$. If $m$ does not appear in configuration $c$, then $S(m, c) = 0$.

# %% [markdown]
# ## All Methods

# %%
metrics_rank = metrics_files_processing(metrics_files[0], flag="rank")
display(metrics_rank)

metrics_rank.to_csv('scicite_ranked_models.csv', index=True)
# Out:
#            Model  Ranking_Score
# 1    QWEN2.5_14B        125.331
# 2   MISTRAL_NEMO         58.609
# 3     GEMMA2-27B         48.205
# 4      GEMMA2-9B         47.786
# 5          QWEN2         31.951
# 6       LLAMA3.1         23.585
# 7         LLAMA3         21.571
# 8    PHI3.5_MINI         18.833
# 9    PHI3_MEDIUM         16.866
# 10     GEMMA2-2B         15.516
# 11   LLAMA3.2_3B         14.547
# 12   LLAMA3.2_1B         11.620

# %% [markdown]
# ### Plot

# %%
metrics_rank_norm = norm_rank(metrics_rank)
plot_rank(metrics_rank_norm, score='rank')

# %% [markdown]
# ## Zero-Shot

# %%
metrics_rank_zero = metrics_files_processing(metrics_files[1], flag="rank")
display(metrics_rank_zero)
# Out:
#            Model  Ranking_Score
# 1    QWEN2.5_14B         20.000
# 2     GEMMA2-27B         10.000
# 3      GEMMA2-9B          6.245
# 4          QWEN2          5.165
# 5   MISTRAL_NEMO          3.604
# 6       LLAMA3.1          3.492
# 7    PHI3.5_MINI          2.935
# 8         LLAMA3          2.734
# 9      GEMMA2-2B          2.339
# 10   PHI3_MEDIUM          1.979
# 11   LLAMA3.2_3B          1.907
# 12   LLAMA3.2_1B          1.660

# %% [markdown]
# ### Plot

# %%
metrics_rank_zero_norm = norm_rank(metrics_rank_zero)
plot_rank(metrics_rank_zero_norm, score='rank')

# %% [markdown]
# ## One-Shot

# %%
metrics_rank_one = metrics_files_processing(metrics_files[2], flag="rank")
display(metrics_rank_one)
# Out:
#            Model  Ranking_Score
# 1    QWEN2.5_14B         39.000
# 2      GEMMA2-9B         16.080
# 3     GEMMA2-27B         13.962
# 4   MISTRAL_NEMO         12.742
# 5          QWEN2          8.124
# 6         LLAMA3          6.124
# 7       LLAMA3.1          6.032
# 8    PHI3.5_MINI          5.909
# 9    PHI3_MEDIUM          4.746
# 10     GEMMA2-2B          4.044
# 11   LLAMA3.2_3B          4.037
# 12   LLAMA3.2_1B          3.320

# %% [markdown]
# ### Plot

# %%
metrics_rank_one_norm = norm_rank(metrics_rank_one)
plot_rank(metrics_rank_one_norm, score='rank')

# %% [markdown]
# ## Few-Shot

# %%
metrics_rank_few = metrics_files_processing(metrics_files[3], flag="rank")
display(metrics_rank_few)
# Out:
#            Model  Ranking_Score
# 1    QWEN2.5_14B         32.165
# 2   MISTRAL_NEMO         21.331
# 3      GEMMA2-9B         14.472
# 4     GEMMA2-27B         11.144
# 5          QWEN2          9.709
# 6       LLAMA3.1          7.445
# 7         LLAMA3          5.935
# 8    PHI3.5_MINI          5.062
# 9    PHI3_MEDIUM          4.757
# 10     GEMMA2-2B          4.465
# 11   LLAMA3.2_3B          4.315
# 12   LLAMA3.2_1B          3.320

# %% [markdown]
# ### Plot

# %%
metrics_rank_few_norm = norm_rank(metrics_rank_few)
plot_rank(metrics_rank_few_norm, score='rank')

# %% [markdown]
# ## Many-Shot

# %%
metrics_rank_many = metrics_files_processing(metrics_files[4], flag="rank")
display(metrics_rank_many)
# Out:
#            Model  Ranking_Score
# 1    QWEN2.5_14B         34.166
# 2   MISTRAL_NEMO         20.932
# 3     GEMMA2-27B         13.099
# 4      GEMMA2-9B         10.989
# 5          QWEN2          8.953
# 6         LLAMA3          6.778
# 7       LLAMA3.1          6.616
# 8    PHI3_MEDIUM          5.384
# 9    PHI3.5_MINI          4.927
# 10     GEMMA2-2B          4.668
# 11   LLAMA3.2_3B          4.288
# 12   LLAMA3.2_1B          3.320

# %% [markdown]
# ### Plot

# %%
metrics_rank_many_norm = norm_rank(metrics_rank_many)
plot_rank(metrics_rank_many_norm, score='rank')

# %% [markdown]
# ## Overall Shot Method Comparison

# %% [markdown]
# ### Plot Methods Grouped

# %%
metrics_rank_dataframes_methods_only = [metrics_rank_zero_norm, metrics_rank_one_norm, metrics_rank_few_norm, metrics_rank_many_norm]
df_labels=['Zero-Shot', 'One-Shot', 'Few-Shot', 'Many-Shot']
model_sort = metrics_rank['Model'].tolist()

metrics_rank_dataframes_methods_only = merge_rank_dataframes(dataframes=metrics_rank_dataframes_methods_only, labels=df_labels, sort=model_sort)

# %%
# plot_rank(metrics_rank_dataframes_methods_only, mode='multi', score='norm')
plot_rank(metrics_rank_dataframes_methods_only, mode='multi', score='rank')

# %% [markdown]
# ### Plot Methods Grouped + Total

# %%
metrics_rank_dataframes = [metrics_rank_norm, metrics_rank_zero_norm, metrics_rank_one_norm, metrics_rank_few_norm, metrics_rank_many_norm]
df_labels=['All Methods', 'Zero-Shot', 'One-Shot', 'Few-Shot', 'Many-Shot']
metrics_rank_all = merge_rank_dataframes(dataframes=metrics_rank_dataframes, labels=df_labels)

# %%
# plot_rank(metrics_rank_all, mode='multi', score='norm')
plot_rank(metrics_rank_all, mode='multi', score='rank')

# %% [markdown]
# ## Merged Plot of Datasets

# %%
scicite_ranked = pd.read_csv('scicite_ranked_models.csv')
acl_arc_ranked = pd.read_csv('acl-arc_ranked_models.csv')

scicite_ranked_norm = norm_rank(scicite_ranked)
acl_arc_ranked_norm = norm_rank(acl_arc_ranked)

merged_ranked_datasets = merge_rank_dataframes([scicite_ranked_norm, acl_arc_ranked_norm], ["scicite", "acl-arc"])

# %%
plot_rank(merged_ranked_datasets, mode='multi', score='rank')

# %% [markdown]
# # Generalized Parameter Analysis

# %%
if 'Top' in metrics_total.columns:
    metrics_total = metrics_total.drop(columns=['Top'])

# top_k = 50
# metrics_total['Top'] = metrics_total.index <= top_k  # Binary indicator for top configs

# top_quantile = 0.1
top_quantile = 0.05
metrics_total['Top'] = metrics_total['F1-Score'] >= metrics_total['F1-Score'].quantile(1 - top_quantile)

# %% [markdown]
# ## 1. Prompting Method
#
# Check the prompting method distribution of the top-K configurations to identify if there is an optimal one.

# %%
method_vc = parameter_distributions(metrics_total, 'Method', 'Method')
display(method_vc)
# Out:
#       Method  Count    Percent
# 1   few-shot     40  47.058824
# 2  many-shot     30  35.294118
# 3   one-shot     14  16.470588
# 4  zero-shot      1   1.176471

# %% [markdown]
# ## 2. Temperature
#
# Check the temperature distribution of the top-K configurations to identify if there is an optimal one.

# %%
temp_vc = parameter_distributions(metrics_total, 'Temperature', 'Temperature')
display(temp_vc)
# Out:
#    Temperature  Count    Percent
# 1          0.2     26  30.588235
# 2          0.0     25  29.411765
# 3          0.5     17  20.000000
# 4          1.0     17  20.000000

# %% [markdown]
# ## 3. System Prompt
#
# Check the System Prompt distribution of the top-K configurations to identify if there is an optimal one.

# %%
sp_vc = parameter_distributions(metrics_total, 'Prompt_Version', 'System Prompt')
display(sp_vc)
# Out:
#   System Prompt  Count    Percent
# 1             3     29  34.117647
# 2             1     28  32.941176
# 3             2     28  32.941176

# %% [markdown]
# ## 4. Query Template
#
# Check the Query Template distribution of the top-K configurations to identify if there is an optimal one.

# %%
qt_vc = parameter_distributions(metrics_total, 'Query_Template', 'Query Template')
display(qt_vc)
# Out:
#   Query Template  Count    Percent
# 1              2     80  94.117647
# 2              1      5   5.882353

# %% [markdown]
# ## 5. Examples Method
#
# Check the Examples Method distribution of the top-K configurations to identify if there is an optimal one.

# %%
em_vc = parameter_distributions(metrics_total, 'Examples_Method', 'Examples Method')
display(em_vc)
# Out:
#   Examples Method  Count    Percent
# 1               2     43  51.190476
# 2               1     41  48.809524

# %% [markdown]
# ## 5. Chi-Square Test of Independence

# %%
for col in ['Method', 'Temperature', 'Prompt_Version', 'Query_Template', 'Examples_Method']:
    contingency = pd.crosstab(metrics_total[col], metrics_total['Top'])
    chi2, p, _, _ = chi2_contingency(contingency)
    print(f"Chi-Square test for {col}: chi2={chi2}, p={p}")
# Out:
# Chi-Square test for Method: chi2=27.484713258344094, p=4.658791875137683e-06
# Chi-Square test for Temperature: chi2=3.6059745528305367, p=0.3072754337366064
# Chi-Square test for Prompt_Version: chi2=11.15249861700166, p=0.0037867418170553207
# Chi-Square test for Query_Template: chi2=41.93804167434999, p=9.42117878727798e-11
# Chi-Square test for Examples_Method: chi2=0.012642225031605562, p=0.9104764045744151
